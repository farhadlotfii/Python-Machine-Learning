# %%
import pandas as pd

# %% [markdown]
# ### read data and information

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.shape
# Out:
# (1310, 14)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.dtypes
# Out:
# pclass       float64
# survived     float64
# name          object
# sex           object
# age          float64
# sibsp        float64
# parch        float64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %%
type(df.name)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### select columns and rows

# %%
df['survived'][0:5]
# Out:
# 0    1.0
# 1    1.0
# 2    0.0
# 3    0.0
# 4    0.0
# Name: survived, dtype: float64

# %%
df.survived[0:5]
# Out:
# 0    1.0
# 1    1.0
# 2    0.0
# 3    0.0
# 4    0.0
# Name: survived, dtype: float64

# %%
df[['survived','age']][10:20]
# Out:
#     survived   age
# 10       0.0  47.0
# 11       1.0  18.0
# 12       1.0  24.0
# 13       1.0  26.0
# 14       1.0  80.0
# 15       0.0   NaN
# 16       0.0  24.0
# 17       1.0  50.0
# 18       1.0  32.0
# 19       0.0  36.0

# %%
df['survived'].value_counts()
# Out:
# 0.0    809
# 1.0    500
# Name: survived, dtype: int64

# %%
df['survived'].value_counts(normalize=True) * 100
# Out:
# 0.0    61.802903
# 1.0    38.197097
# Name: survived, dtype: float64

# %% [markdown]
# ### crosstab

# %%
pd.crosstab(df.sex, df.survived)
# Out:
# survived  0.0  1.0
# sex
# female    127  339
# male      682  161

# %%
pd.crosstab(df.sex, df.survived, normalize="index") * 100
# Out:
# survived        0.0        1.0
# sex
# female    27.253219  72.746781
# male      80.901542  19.098458

# %%
pd.crosstab(df.sex, df.survived, normalize="columns") * 100
# Out:
# survived        0.0   1.0
# sex
# female    15.698393  67.8
# male      84.301607  32.2

# %%
pd.crosstab(df.sex, df.survived, normalize="all") * 100
# Out:
# survived        0.0        1.0
# sex
# female     9.702063  25.897632
# male      52.100840  12.299465

# %% [markdown]
# ### EDA

# %%
below_5_years = df[df.age <= 5]
len(below_5_years)
# Out:
# 56

# %%
below_5_years_survived = df[(df["age"] <= 5)&(df.survived==1)]
len(below_5_years_survived)
# Out:
# 37

# %%
df[df.age <= 5]["survived"].value_counts(normalize=True) * 100
# Out:
# 1.0    66.071429
# 0.0    33.928571
# Name: survived, dtype: float64

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df[df.name.str.contains("Allen", na=False)]
# Out:
#      pclass  survived                                              name  \
# 0       1.0       1.0                     Allen, Miss. Elisabeth Walton
# 342     2.0       1.0  Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 618     3.0       0.0                          Allen, Mr. William Henry
#
#         sex   age  sibsp  parch  ticket      fare cabin embarked boat  body  \
# 0    female  29.0    0.0    0.0   24160  211.3375    B5        S    2   NaN
# 342  female  36.0    0.0    3.0  230136   39.0000    F4        S   11   NaN
# 618    male  35.0    0.0    0.0  373450    8.0500   NaN        S  NaN   NaN
#
#                                              home.dest
# 0                                         St Louis, MO
# 342                 Guntur, India / Benton Harbour, MI
# 618  Lower Clapton, Middlesex or Erdington, Birmingham

# %%
df.embarked.unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
mask1 = df.survived == 1
mask2 = df.age <= 5
columns = ['age','sex','pclass']

df[mask1 & mask2][columns][0:10]
# Out:
#         age     sex  pclass
# 1    0.9167    male     1.0
# 94   4.0000    male     1.0
# 339  1.0000    male     2.0
# 340  4.0000  female     2.0
# 359  0.8333    male     2.0
# 427  0.6667    male     2.0
# 478  1.0000  female     2.0
# 479  3.0000  female     2.0
# 492  1.0000    male     2.0
# 514  2.0000    male     2.0

# %%
df[df.age.isnull()] [['age', 'survived', 'sex', 'pclass']]
# Out:
#       age  survived     sex  pclass
# 15    NaN       0.0    male     1.0
# 37    NaN       1.0    male     1.0
# 40    NaN       0.0    male     1.0
# 46    NaN       0.0    male     1.0
# 59    NaN       1.0  female     1.0
# ...   ...       ...     ...     ...
# 1297  NaN       0.0    male     3.0
# 1302  NaN       0.0    male     3.0
# 1303  NaN       0.0    male     3.0
# 1305  NaN       0.0  female     3.0
# 1309  NaN       NaN     NaN     NaN
#
# [264 rows x 4 columns]

# %% [markdown]
# ### group by

# %%
df.groupby('pclass')['age'].mean().reset_index()
# Out:
#    pclass        age
# 0     1.0  39.159918
# 1     2.0  29.506705
# 2     3.0  24.816367

# %%
df.groupby(['pclass','sex'])['age'].mean().reset_index()
# Out:
#    pclass     sex        age
# 0     1.0  female  37.037594
# 1     1.0    male  41.029250
# 2     2.0  female  27.499191
# 3     2.0    male  30.815401
# 4     3.0  female  22.185307
# 5     3.0    male  25.962273

# %% [markdown]
# ### Sort Values

# %%
df.sort_values('age', ascending=True)
# Out:
#       pclass  survived                                     name     sex  \
# 763      3.0       1.0  Dean, Miss. Elizabeth Gladys "Millvina"  female
# 747      3.0       0.0  Danbom, Master. Gilbert Sigvard Emanuel    male
# 1240     3.0       1.0          Thomas, Master. Assad Alexander    male
# 427      2.0       1.0                Hamalainen, Master. Viljo    male
# 1111     3.0       0.0           Peacock, Master. Alfred Edward    male
# ...      ...       ...                                      ...     ...
# 1297     3.0       0.0                   Wiseman, Mr. Phillippe    male
# 1302     3.0       0.0                        Yousif, Mr. Wazli    male
# 1303     3.0       0.0                    Yousseff, Mr. Gerious    male
# 1305     3.0       0.0                    Zabour, Miss. Thamine  female
# 1309     NaN       NaN                                      NaN     NaN
#
#          age  sibsp  parch              ticket     fare cabin embarked boat  \
# ...

# %% [markdown]
# ### Selection Data

# %%
df.sample(5)
# Out:
#       pclass  survived                                       name     sex  \
# 1191     3.0       0.0             Saundercock, Mr. William Henry    male
# 928      3.0       0.0  Khalil, Mrs. Betros (Zahie "Maria" Elias)  female
# 888      3.0       0.0                 Johanson, Mr. Jakob Alfred    male
# 962      3.0       0.0                          Lennon, Mr. Denis    male
# 1241     3.0       0.0                      Thomas, Mr. Charles P    male
#
#        age  sibsp  parch     ticket     fare cabin embarked boat   body  \
# 1191  20.0    0.0    0.0  A/5. 2151   8.0500   NaN        S  NaN    NaN
# 928    NaN    1.0    0.0       2660  14.4542   NaN        C  NaN    NaN
# 888   34.0    0.0    0.0    3101264   6.4958   NaN        S  NaN  143.0
# 962    NaN    1.0    0.0     370371  15.5000   NaN        Q  NaN    NaN
# 1241   NaN    1.0    0.0       2621   6.4375   NaN        C  NaN    NaN
#
#      home.dest
# 1191       NaN
# 928        NaN
# 888        NaN
# 962        NaN
# ...

# %%
df.iloc[[3, 4], [1, 2, 6]]
# Out:
#    survived                                             name  parch
# 3       0.0             Allison, Mr. Hudson Joshua Creighton    2.0
# 4       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    2.0

# %%
df.iloc[9:25, 2:5]
# Out:
#                                                  name     sex   age
# 9                             Artagaveytia, Mr. Ramon    male  71.0
# 10                             Astor, Col. John Jacob    male  47.0
# 11  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0
# 12                      Aubart, Mme. Leontine Pauline  female  24.0
# 13                       Barber, Miss. Ellen "Nellie"  female  26.0
# 14               Barkworth, Mr. Algernon Henry Wilson    male  80.0
# 15                                Baumann, Mr. John D    male   NaN
# 16                           Baxter, Mr. Quigg Edmond    male  24.0
# 17    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 18                              Bazzani, Miss. Albina  female  32.0
# 19                               Beattie, Mr. Thomson    male  36.0
# 20                      Beckwith, Mr. Richard Leonard    male  37.0
# 21   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# ...

# %%
df.iloc[:, 2:5]
# Out:
#                                                  name     sex      age
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000
# 1                      Allison, Master. Hudson Trevor    male   0.9167
# 2                        Allison, Miss. Helen Loraine  female   2.0000
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# ...                                               ...     ...      ...
# 1305                            Zabour, Miss. Thamine  female      NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.5000
# 1307                              Zakarian, Mr. Ortin    male  27.0000
# 1308                               Zimmerman, Mr. Leo    male  29.0000
# 1309                                              NaN     NaN      NaN
#
# [1310 rows x 3 columns]

# %%
df.loc[:, ['pclass', 'embarked']]
# Out:
#       pclass embarked
# 0        1.0        S
# 1        1.0        S
# 2        1.0        S
# 3        1.0        S
# 4        1.0        S
# ...      ...      ...
# 1305     3.0        C
# 1306     3.0        C
# 1307     3.0        C
# 1308     3.0        S
# 1309     NaN      NaN
#
# [1310 rows x 2 columns]

# %%
df.query('survived == 1 and embarked == "S" and pclass == 1 and fare > 200 ')
# Out:
#      pclass  survived                                               name  \
# 0       1.0       1.0                      Allen, Miss. Elisabeth Walton
# 24      1.0       1.0                                  Bird, Miss. Ellen
# 111     1.0       1.0                     Fortune, Miss. Alice Elizabeth
# 112     1.0       1.0                         Fortune, Miss. Ethel Flora
# 113     1.0       1.0                         Fortune, Miss. Mabel Helen
# 116     1.0       1.0                Fortune, Mrs. Mark (Mary McDougald)
# 180     1.0       1.0                             Kreuchen, Miss. Emilie
# 193     1.0       1.0                  Madill, Miss. Georgette Alexandra
# 238     1.0       1.0  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
#
#         sex   age  sibsp  parch    ticket      fare        cabin embarked  \
# 0    female  29.0    0.0    0.0     24160  211.3375           B5        S
# 24   female  29.0    0.0    0.0  PC 17483  221.7792          C97        S
# ...

# %%
dc = {u'2012-06-08': 388,
 u'2012-06-09': 388,
 u'2012-06-10': 388}
dc
# Out:
# {'2012-06-08': 388, '2012-06-09': 388, '2012-06-10': 388}

# %%
pd.DataFrame(dc.items(), columns=['Date', 'DateValue'])
# Out:
#          Date  DateValue
# 0  2012-06-08        388
# 1  2012-06-09        388
# 2  2012-06-10        388
